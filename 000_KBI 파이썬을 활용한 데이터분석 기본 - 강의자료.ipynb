# %% [markdown]
# # <span style="color:blue">"파이썬을 활용한 데이터분석 기본" 강의자료</span>
#
#                                                                2018 이승준 FinanceData.KR
#
#
# <br>
# * ## <span style="color:gray">1회차 - 데이터 분석 환경 구축과 파이썬 언어 기본</span>
#
#   * #### 사전 다운로드와 설치
#     - 크롬 브라우저   https://google.co.kr/chrome
#     - 아나콘다 (64비트)   https://www.anaconda.com/download/
#
#   * #### 오리엔테이션
#     - 오리엔테이션
#       https://nbviewer.ipython.org/21a72ded62bf100136d1b9745213bc06
#     - T아카데미 Python 프로그래밍 기초 (정리법)
#       https://docs.google.com/document/d/12zpo8JNrfE4V6PA9PQW426wIziZcbnPtjNo0OibaXfk
#
#   * #### 파이썬 데이터 분석 환경 만들기
#     - 데이터 분석 환경 만들기 - 아나콘다
#       https://nbviewer.ipython.org/737719e50488821340b68a0d70bf0ffb
#
#   * #### 파이썬 언어와 소개
#     - 파이썬 프로그래밍 언어 소개
#       https://nbviewer.ipython.org/fb5c8224cc3c579101b6a3a16d907113
#     - 주피터 노트북
#       https://nbviewer.jupyter.org/d0ef3dda3518e1d555955afc7d8381d2
#     - Jupyter Notebook 키보드 바로가기
#       https://nbviewer.jupyter.org/917ff3b359f283ccc7ee926e2aeeaed9
#
#   * #### LAB (실습)
#     - 파이썬 데이터 분석 환경 구축 및 주피터 노트북 사용
#     - 간단한 파이썬 프로그래밍 실습
#     - LAB 주피터 노트북 (Jupyter Notebook)
#       https://nbviewer.jupyter.org/8dd4a6ba41fe97b7dc7795e8f90a8ac2
#     - 주피터 노트북 사용법 (동영상 강좌)
#       https://photos.app.goo.gl/81xCYXSYjbWyOAuz2
#
#   * #### 파이썬 언어 기본 I
#     - PART 1 - 변수와 값, 기본 데이터 타입, 출력
#       https://nbviewer.ipython.org/9d7ddfa86e60d9a212dc8c72d54dbad8
#     - PART 2 - 연산자, 문자열
#       https://nbviewer.ipython.org/d5a97d6465d987788e6a02ee4edebbc6
#     - PART 3 - 흐름 제어
#       https://nbviewer.ipython.org/96d1491a699fb8288e781b5db5e2691b
#
# ---
#
# * ## <span style="color:gray">2회차 - 파이썬 언어 기본과 금융데이터 수집</span>
#
#   * #### 파이썬 언어 기본 II
#     - PART 4 - 자료구조 - 리스트, 튜플, 딕셔너리
#       https://nbviewer.ipython.org/aa2bc96aadf37a9440891d0bc89abb1a
#     - PART 5 - 함수와 모듈
#       https://nbviewer.ipython.org/5572cd2d5b271d3c7122034737747a4a
#     - PART 6 - 날짜와 시간, 요약 통계, 파일 입출력
#       https://nbviewer.ipython.org/6b9ea9c4a1a81b213479bf61fb594ee5
#     - 파이썬 문법 총정리
#
#   * #### LAB (실습)
#     - 파이썬 코딩 실습(기본 단계별)
#
#   * #### 웹사이트에서 데이터 수집하기 (크롤링)
#     - 데이터 크롤링 01 - 개요
#       https://nbviewer.ipython.org/0bcce64a22feb3e2640e7086908fd812
#     - 데이터 크롤링 02 - requests, BeautifulSoup <br>
#       https://nbviewer.ipython.org/f03474b4c1ea11b2a05af169f9db60d5
#
#   * #### 마켓 데이터 크롤링
#     - 마켓 데이터 크롤링 - 개요
#       https://nbviewer.ipython.org/fdb1bbf53d95adef83cbb6c7ee18e44f
#
#   * #### 전자공시시스템(DART) 오픈 API
#     - DART 01 - Open API 개요
#       http://nbviewer.ipython.org/7329c9cb36d439db94f23dd992e9e586
#     - DART 02 - 개별 보고서 하위 문서
#       http://nbviewer.ipython.org/5ac82ae7d18fcb64782b44c3e8aa1157
#     - DART 03 - 개별 보고서 첨부파일
#       http://nbviewer.ipython.org/0be7fd5cf8e787e2df58ca8d6c5fd5c5
#     - (참고) DART DB (dart.db) 데이터 (579M, 보고서 링크 256만건 )
#       https://www.dropbox.com/s/8ezmbs34lax4fx2/dart.db?dl=0
#
#   * #### 한국은행 OpenAPI
#     - 마켓 데이터 크롤링 600 - 한국은행 01 서비스 목록
#       https://nbviewer.ipython.org/734fa7513d883f0f1339510522194e4a
#     - 마켓 데이터 크롤링 600 - 한국은행 02 본원 통화
#       https://nbviewer.ipython.org/8701cae2295c85bf561386f3f64881f2
#
#   * #### 채권 데이터
#     - 채권 01 - 한국신용평가 국고채 수익률
#       https://nbviewer.ipython.org/c39c6eb306b6338d8ccfb1bea59280c8
#     - 채권 02 - 금융투자협회 채권정보
#       https://nbviewer.ipython.org/3b4f53cae6d37bc6a5d42b8dcea86e36
#     - 채권 03 - 금융투자협회 채권정보 (기간지정)
#       https://nbviewer.ipython.org/873577f10e3de713ccf93fe2f487a06a
#
#   * #### LAB (실습)
#     - 데이터 크롤링 -- 네이버 실시간 검색어, 다음 실시간 급등
#     - 전자공시 데이터 추가 데이터 수집 및 빈도 분석, 보고서 제목 검색
#
# ---
#
# * ## <span style="color:gray">3회차 - Numpy와 Pandas, 글로벌 금융데이터 수집</span>
#
#   * ### Numpy
#     - 금융 데이터 분석을 위한 Numpy
#       https://nbviewer.jupyter.org/274d1a051b8ef10379b35b3fa72dd931
#
#   * ### Pandas
#     - pandas 01 - Introduction
#       https://nbviewer.jupyter.org/f8001ebff7536e79b5ec8afa8c0c780e
#     - Pandas 02 - Series
#       https://nbviewer.jupyter.org/799845b86f2e545dfef7cc556d398419
#     - pandas 03 - DataFrame
#       https://nbviewer.jupyter.org/8015a3de69b613d639511762dcfce62a
#     - pandas 04 - 고급 인덱싱
#       https://nbviewer.jupyter.org/900e536d361d167aa5f9ea4dfda8f153
#     - pandas 05 - 시계열
#       https://nbviewer.jupyter.org/0e8440831d7d4e1b93dddbc358d89e59
#     - pandas-06 - 병합, 피벗, 인덱스
#       https://nbviewer.jupyter.org/975783d57162a81f0ec60a2dc88c921c
#
#   * ### 데이터 베이스 SQL (SQLite)
#     - SQLite 01 - Introduction
#       https://nbviewer.jupyter.org/8ca35e36aa9801d37704e8ba2858c91c
#     - SQLite 02 - SQL 과 DataFrame
#       https://nbviewer.jupyter.org/371c48734ed937651e9127cdb43a9919
#
#   * ### LAB (실습)
#     - LAB 종목 검색기
#       https://nbviewer.jupyter.org/905af0518362351d854f9ee81f4a99fa
#
#   * ### 글로벌 데이터 크롤링
#     - 마켓 데이터 크롤링 - 해외주식 01 - 종목 티커와 지수
#       https://nbviewer.ipython.org/4f734b43c74d8539395edfdea550254a
#     - 마켓 데이터 크롤링 - 해외주식 02 - 야후 파이낸스 구글 파이낸스
#       https://nbviewer.ipython.org/06472cdcf3923a7a1426e265eead8dcb
#     - 마켓 데이터 크롤링 - FRED
#       https://nbviewer.ipython.org/8c3bf5f99d8127c7a7fc79f22049b1ab
#     - 국제 상품 가격 데이터
#       https://nbviewer.ipython.org/d681c1a29bb4a58b8703f0e34c2c6fce
#
# ---
#
# * ## <span style="color:gray">4회차 - 데이터 시각화</span>
#
#   * ### 시각화 (Visualization)
#     - Visualization 01 Matplotlib
#       https://nbviewer.jupyter.org/3ae09e20d1431f5e417e84f89ae77e9b
#     - Visualization 02 Series and DataFrame
#       https://nbviewer.jupyter.org/a58e6453fbc8518b3f968fa2a6f301ce
#     - Visualization 03 여러가지 그래프
#       https://nbviewer.jupyter.org/6b6c16134c5ff25c23300e03863550e7
#     - Visualization 04 선형차트 로그차트
#       https://nbviewer.jupyter.org/78b80a162b871795755aa7cc36f8df1d
#     - Visualization 05 사례분석 100대 광고주
#       https://nbviewer.jupyter.org/793932e0aab322d062edb4b381c73aa8
#
#   * ### 웹 기반 시각화
#     - 웹기반 데이터 시각화 01 - 시각화 도구와 시계열 데이터
#       https://nbviewer.jupyter.org/c7e37bbf3333238be61e7fdc20edcbd0
#     - 웹기반 데이터 시각화 02 - EDA
#       https://nbviewer.jupyter.org/329e29cc520f171089e0a69bb8e2ae71
#     - 웹기반 데이터 시각화 03 - D3 소개
#       https://nbviewer.jupyter.org/21d6e98316f38837700073ecbe21208a
#     - MPL D3
#       https://nbviewer.jupyter.org/82af2cfee91f5f8a6977
#
#   * ### LAB  실습
#     - 간단한 D3 예제
#       https://www.dropbox.com/s/tikz4clckyiga61/first_d3_chart.zip?dl=0
#     - 다양한 기술적 분석 데이터 차트 그리기
#
#   * ### 참고 자료
#     - 한스로슬링 2006년 강연 제목 그대로 "이제껏 보지 못했던 최고의 통계"
#       https://www.facebook.com/financedata/posts/1865667487055587
#     - 맑은고딕폰트
#       https://www.dropbox.com/s/wbu7npudkyr5d7i/malgunbd.ttf?dl=0
#
# ---
#
# * ## <span style="color:gray">5회차 - 데이터 분석 기본과 엑셀 리포트 자동화</span>
#
#   * ### 금융 통계
#     - 금융 통계학 기본 01 - 소개
#       https://nbviewer.jupyter.org/55ec7ea81b7e539f7fac784053e1b626
#     - 금융 통계학 기본 02 - 기술 통계
#       https://nbviewer.jupyter.org/388b36c84cd993b8a149b9fa10f8e476
#     - 금융 통계학 기본 03 - 확률분포
#       https://nbviewer.ipython.org/6cb8064dc3616d13b720bddc1a62a584
#     - 금융 통계학 기본 04 - 상관 분석, 회귀분석
#       https://nbviewer.ipython.org/4bc0b7638539f1e3a70965b3c0dc8d23
#
#   * ### 별첨
#     - 기하평균의 중요성
#       https://nbviewer.ipython.org/19eee53aacf58cd9a5b7d7dca9595a5a
#
#   * ### LAB 실습
#     - 회귀분석 실습, 상관 분석 실습
#
#   * ### 이메일 리포팅 자동화
#     - 이메일 리포팅(gmail)
#       https://nbviewer.jupyter.org/0e516795936598624a957b64ee7a6ffc
#
#   * ### 엑셀 자동화
#     - 파이썬 엑셀 01 - pandas DataFrame
#       https://nbviewer.jupyter.org/8a668109436927809ca5f063b8be3878
#     - 파이썬 엑셀 02 - OpenPyXL
#       https://nbviewer.jupyter.org/9ee944788aaf5cedf22aacbc856970e5
#
#   * ### 보고서 생성
#     - 보고서 01 - 템플릿 엔진
#       http://nbviewer.jupyter.org/af593691445985042f9f090ef48ee885
#     - 보고서 02 - 보고서 생성
#       http://nbviewer.jupyter.org/a1ff6e8e9b99a91eec5fc7bd3064b877
#
#   * ### LAB 실습
#     - 보고서 생성, 엑셀 병합 실습
#
#   * ### 강의 마무리
#
# ---
#
# <br>
# * ### <span style="color:gray">참고 자료</span>
#   * [보조 교재] 파이썬 라이브러리를 활용한 데이터 분석(수정보완판)
#      http://www.hanbit.co.kr/store/books/look.php?p_code=B6540908288
#
#   * 크롤링 관련 온라인 강좌
#     -  https://opentutorials.org/course/2039 [생활코딩] HTML 수업
#     -  https://opentutorials.org/course/580 [생활코딩] 크롬 개발자 도구
#
#   * 추천 무료 온라인 강좌
#     https://nbviewer.jupyter.org/urls/financedata.github.io/posts/recommended-free-online-courses.ipynb
#
#   * 파이썬 패키지 오프라인 설치
#     https://gist.github.com/4ab214a2f7ff2d3b0868b6294d72571c
#
#
# * ### <span style="color:gray">추가 실습</span>
#   * 크롤링 예제 기업 개요 (네이버)
#     http://nbviewer.jupyter.org/25237480d88e809035e4786f3db7360d
#
#   * pandas 실습 - 이동평균, 시차를 부여한 상관계수
#     http://nbviewer.jupyter.org/5d5829bf9cc2b7e019463ca922375950
#
#   * FRED 환율 데이터 SQLite
#     http://nbviewer.jupyter.org/2b8e65678def920e536408d1e389c78b
#
#
# * ### <span style="color:gray">QUIZ (제출: plusjune@gmail.com 이승준)</span>
#   * 파이썬 프로그래밍 LAB 01
#     - (문제) https://nbviewer.jupyter.org/7ab94d172f82fabc2a3f6c030184a414
#     - (솔루션) https://nbviewer.jupyter.org/d768ba4bb04a61dd39d679541c178766
#
#   * 파이썬 프로그래밍 LAB 02
#     - 서식 제목, 텍스트 포함한 보고서 HTML 생성
#     - 데이터(DataFrame)로 부터 차트의 이미지, 표를 생성하여 포함
#     - 데이터(DataFrame)로 엑셀파일 생성
#
#
# * ### <span style="color:gray">질문</span>
#   * https://m.me/plusjune (페이스북 메신저)
#   * plusjune@gmail.com  (이메일)
#   * 010-9690-4558
#
# <br>
# <br>
# 2018 FinanceData.KR
